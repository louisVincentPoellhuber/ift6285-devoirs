# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import treebank
from nltk.grammar import induce_pcfg
from nltk import Nonterminal, ProbabilisticProduction
from nltk.parse import ViterbiParser
import time

from devoir4 import *

# %%
column_names = ["Source_Code", "Acceptability_Label", "Acceptability_Judgment", "Sentence"]

# %%
df = pd.read_csv(r"C:\Users\barka\Desktop\NLP\ift6285-devoirs\Devoir 4\data\cola_public\tokenized\in_domain_dev.tsv", delimiter='\t', header=None, names=column_names)
df.head()
# Out:
#   Source_Code  Acceptability_Label Acceptability_Judgment  \
# 0        gj04                    1                    NaN
# 1        gj04                    1                    NaN
# 2        gj04                    1                    NaN
# 3        cj99                    1                    NaN
# 4        cj99                    0                      *
#
#                                             Sentence
# 0   the sailors rode the breeze clear of the rocks .
# 1  the weights made the rope stretch over the pul...
# 2        the mechanical doll wriggled itself loose .
# 3      if you had eaten more , you would want less .
# 4         as you eat the most , you want the least .

# %%
problematic_sentences_df = df[df['Acceptability_Label'] == 0]

problematic_sentences_df.head()
# Out:
#    Source_Code  Acceptability_Label Acceptability_Judgment  \
# 4         cj99                    0                      *
# 5         cj99                    0                      *
# 6         cj99                    0                      *
# 13        cj99                    0                      *
# 16        bc01                    0                      *
#
#                                              Sentence
# 4          as you eat the most , you want the least .
# 5   the more you would want , the less you would e...
# 6   i demand that the more john eat , the more he ...
# 13  the more does bill smoke , the more susan hate...
# 16       who does john visit sally because he likes ?

# %%
problematic_sentences = problematic_sentences_df["Sentence"].values
len(problematic_sentences)
# Out:
# 162

# %%
tic = time.perf_counter()
productions = get_PTB_produtions()
print(f"Took {time.perf_counter() - tic}s.")
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\barka\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# Took 11.54024629999185s.

# %%
tic = time.perf_counter()
full_grammar = induce_pcfg(Nonterminal("S"), productions)
print(f"Took {time.perf_counter() - tic}s.")
# Out:
# Took 1.3252873999881558s.

# %%
parser = ViterbiParser(full_grammar)

# %%
ptb_sentences = treebank.sents()

known_words = set(word.lower() for sentence in ptb_sentences for word in sentence)

# %%
unk_token = 'UNK'
modified_sentences = []

for sentence in problematic_sentences:
    words = sentence.split()
    modified_words = [word if word.lower() in known_words else unk_token for word in words]
    modified_sentence = ' '.join(modified_words)
    modified_sentences.append(modified_sentence)

# %%
modified_sentences
# Out:
# ['as you eat the most , you want the least .',
#  'the more you would want , the less you would eat .',
#  'i demand that the more john eat , the more he UNK .',
#  'the more does bill smoke , the more susan UNK him .',
#  'who does john visit UNK because he UNK ?',
#  'mickey looked up it .',
#  'the box contained the ball from the tree .',
#  'the tube was escaped by gas .',
#  'what the water did to the bottle was fill it .',
#  'what the water did to the whole bottle was fill it .',
#  'mary UNK plays the UNK .',
#  'sue gave to bill a book .',
#  'they represented seriously to the dean mary as a genuine UNK .',
#  'us UNK they .',
#  'mary intended john to go abroad .',
#  "we wanted to invite someone , but we could n't decide who to .",
#  'mary came to be introduced by the UNK and i also came to be .',
#  "i know which book UNK did n't read for class , and which book lilly did it for him .",
#  "this is the book which bob reviewed , and this is the one which fred wo n't do it .",
#  "i know which book UNK read , and which book bob read my report that you had n't .",
#  'the problem perceives easily .',
#  'which report that john was UNK did he submit ?',
#  'a proof that the claim had been made was given that john had UNK .',
#  'the mayor regarded as being absurd the proposal to build a sidewalk from UNK to smith .',
#  'i want that bill left to remain a secret .',
#  'i know a man who tom drives as drives .',
#  'UNK UNK , which is against the law , are hard to UNK .',
#  'himself is understood by UNK .',
#  'the proof this set is UNK is difficult .',
#  'the UNK which henry plays the UNK and UNK sound lousy .',
#  "which boy 's did we UNK UNK 's employer president ?",
#  'i live at the place where route 150 UNK the hudson river and my UNK lives at it too .',
#  'UNK was gotten of a plot to negotiate an UNK end to the war in UNK .',
#  'which UNK did mike UNK that she never UNK ?',
#  'which girl did mike UNK never UNK this UNK ?',
#  "i wo n't have some money .",
#  "here 's a knife with which for you to cut up the UNK .",
#  'the younger woman might have been tall and , and the older one definitely was , UNK .',
#  'the UNK are ready for for you to put on to be planned .',
#  'my mother is easy to please my father and .',
#  'that the UNK spoke to the UNK about it yesterday is UNK , that UNK .',
#  'every student , and he wears UNK , is a UNK .',
#  "i ca n't remember the name of somebody who had UNK .",
#  'no writer , and no playwright , meets in UNK .',
#  'no writer , nor any playwright , meets in UNK .',
#  'UNK gave the ball out of the basket .',
#  'UNK offered the ball out of the basket .',
#  'no one can UNK that comment to you .',
#  'i lent the book UNK to tony .',
#  'the UNK dumped the UNK with apples .',
#  'UNK broke bill on the UNK .',
#  'UNK came the UNK .',
#  'brian UNK the UNK with the stick .',
#  'they praised the UNK in the UNK .',
#  'paperback books lift onto the table easily .',
#  'the books lifted onto the table .',
#  'UNK UNK UNK at the truck .',
#  'UNK UNK at the toast .',
#  'carla slid at the book .',
#  'packages drive easily to new york .',
#  'the UNK pushed .',
#  'a job offered .',
#  'UNK kept the UNK with the papers .',
#  'UNK UNK the sugar and the UNK .',
#  'this UNK and that UNK differ apart .',
#  'the UNK UNK the contract with his name .',
#  'i UNK a UNK .',
#  'the children UNK .',
#  'UNK said about the present conditions .',
#  'UNK UNK .',
#  'linda UNK her UNK .',
#  'my heart is UNK me .',
#  'i UNK the door .',
#  'the UNK UNK with many UNK .',
#  'there presented itself a UNK opportunity yesterday .',
#  'many information was provided .',
#  'john offers many advice .',
#  'UNK you !',
#  'they have no in .',
#  'some my jobs are in jeopardy .',
#  'it was the UNK met that several young students in the park last night .',
#  'the UNK UNK of their leader .',
#  'john sounded very .',
#  'a good friend is remained to me by him .',
#  'john put under the UNK .',
#  'UNK depends for UNK .',
#  'UNK put in the box .',
#  'that fred was UNK nominated bill .',
#  'john paid me against the book .',
#  "students studying english UNK UNK 's heart of UNK while at university .",
#  'neither of students failed .',
#  'i UNK some of water .',
#  'he UNK yourself .',
#  'john is easy to please UNK .',
#  'there seemed to be intelligent .',
#  'we believed john to be a fountain in the park .',
#  'it UNK to leave the country .',
#  'there is believed to be sheep in the park .',
#  'i hope to would study in france .',
#  'john will rain tomorrow .',
#  'we expect there to will rain .',
#  'did the child be in the school ?',
#  'a pound was weighed by the book .',
#  'fed knows which UNK her to vote for .',
#  'which house does your friend live ?',
#  'jack is the person with whom UNK fell in UNK with .',
#  'which UNK did you get UNK because mary talked about ?',
#  'who achieved the best result was UNK .',
#  'that he was UNK , john UNK .',
#  'i gave mary after the party a book .',
#  "because she 's so UNK , as for mary i really like her .",
#  "any trouble is what i do n't want .",
#  'UNK UNK himself .',
#  'blue leather shows herself that UNK is pretty .',
#  'i hit that you knew the answer .',
#  'the book of UNK and from UNK takes a very long time to read .',
#  "the building 's the roof is UNK .",
#  "the UNK 's the UNK is dark black .",
#  'UNK thinks that andy to eat UNK UNK UNK bars .',
#  'did UNK his homework ?',
#  "if i am a rich man , i 'd buy a diamond ring .",
#  'was UNK .',
#  'john thinks that mary UNK himself .',
#  "any man did n't eat dinner .",
#  'you may pick every UNK , but leave a few for mary .',
#  'the UNK which mary made and UNK UNK has been UNK .',
#  'UNK alienated UNK and UNK his UNK .',
#  'which article did UNK file papers without reading ?',
#  'she goes and buying some UNK .',
#  'UNK and UNK is happy .',
#  'put a picture of bill on your UNK before tomorrow , this girl in the red UNK will put a picture of bill on your UNK before tomorrow .',
#  'picture of bill , this girl in the red UNK will put a picture of bill on your UNK before tomorrow .',
#  'john UNK mary left .',
#  'mary UNK that bill will come .',
#  'UNK will UNK .',
#  "herself UNK mary 's mother .",
#  "john 's mother UNK himself .",
#  'mary UNK himself to john .',
#  'john heard that they criticized themselves .',
#  'you should sit before there .',
#  'everyone hopes everyone to sleep .',
#  'only UNK UNK UNK giving the blood , sweat and UNK speech .',
#  'i saw bill while you did so mary .',
#  'what mary did bill was give a book .',
#  'UNK UNK',
#  'UNK UNK up the UNK',
#  'UNK you !',
#  'what did you ask who UNK gave ?',
#  'UNK tried the UNK to poison her children .',
#  'i UNK that she was happy',
#  'UNK is having fought the UNK .',
#  'UNK thought that himself was happy .',
#  'i thought he UNK UNK',
#  'what did you ask who saw ?',
#  'he can will go',
#  'how fierce the battle ?',
#  'which UNK did you ask which city UNK ?',
#  'i UNK when could we leave .',
#  'the UNK is UNK the UNK',
#  'i would like to could swim',
#  'the UNK ran',
#  'UNK became a UNK UNK .']

# %%
non_terminals = set([Nonterminal(nt) for sent in modified_sentences for nt in sent.split() if isinstance(Nonterminal(nt), Nonterminal)])

# %%
non_terminals
# Out:
# {!,
#  'd,
#  's,
#  ,,
#  .,
#  150,
#  ?,
#  UNK,
#  a,
#  about,
#  abroad,
#  absurd,
#  achieved,
#  advice,
#  after,
#  against,
#  alienated,
#  also,
#  am,
#  an,
#  and,
#  andy,
#  answer,
#  any,
#  apart,
#  apples,
#  are,
#  article,
#  as,
#  ask,
#  at,
#  ball,
#  bars,
#  basket,
#  battle,
#  be,
#  became,
#  because,
#  been,
#  before,
#  being,
#  believed,
#  best,
#  bill,
#  black,
#  blood,
#  blue,
#  bob,
#  book,
#  books,
#  bottle,
#  box,
#  boy,
#  brian,
#  broke,
#  build,
#  building,
#  but,
#  buy,
#  buying,
#  by,
#  ca,
#  came,
#  can,
#  carla,
#  child,
#  children,
#  city,
#  claim,
#  class,
#  come,
#  comment,
#  conditions,
#  contained,
#  contract,
#  could,
#  country,
#  criticized,
#  cut,
#  dark,
#  dean,
#  decide,
#  definitely,
#  demand,
#  depends,
#  diamond,
#  did,
#  differ,
#  difficult,
#  dinner,
#  do,
#  does,
#  door,
#  drive,
#  drives,
#  dumped,
#  easily,
#  easy,
#  eat,
#  employer,
#  end,
#  english,
#  escaped,
#  every,
#  everyone,
#  expect,
#  failed,
#  father,
#  fed,
#  fell,
#  few,
#  fierce,
#  file,
#  fill,
#  for,
#  fought,
#  fountain,
#  france,
#  fred,
#  friend,
#  from,
#  gas,
#  gave,
#  genuine,
#  get,
#  girl,
#  give,
#  given,
#  giving,
#  go,
#  goes,
#  good,
#  gotten,
#  had,
#  happy,
#  hard,
#  has,
#  have,
#  having,
#  he,
#  heard,
#  heart,
#  henry,
#  her,
#  here,
#  herself,
#  him,
#  himself,
#  his,
#  hit,
#  homework,
#  hope,
#  hopes,
#  house,
#  how,
#  hudson,
#  i,
#  if,
#  in,
#  information,
#  intelligent,
#  intended,
#  introduced,
#  invite,
#  is,
#  it,
#  itself,
#  jack,
#  jeopardy,
#  job,
#  jobs,
#  john,
#  kept,
#  knew,
#  knife,
#  know,
#  knows,
#  last,
#  law,
#  leader,
#  least,
#  leather,
#  leave,
#  left,
#  lent,
#  less,
#  lift,
#  lifted,
#  like,
#  lilly,
#  linda,
#  live,
#  lives,
#  long,
#  looked,
#  lousy,
#  made,
#  man,
#  many,
#  mary,
#  may,
#  mayor,
#  me,
#  meets,
#  met,
#  mickey,
#  might,
#  mike,
#  money,
#  more,
#  most,
#  mother,
#  my,
#  n't,
#  name,
#  negotiate,
#  neither,
#  never,
#  new,
#  night,
#  no,
#  nominated,
#  nor,
#  of,
#  offered,
#  offers,
#  older,
#  on,
#  one,
#  only,
#  onto,
#  opportunity,
#  out,
#  packages,
#  paid,
#  paperback,
#  papers,
#  park,
#  party,
#  perceives,
#  person,
#  pick,
#  picture,
#  place,
#  planned,
#  plays,
#  playwright,
#  please,
#  plot,
#  poison,
#  pound,
#  praised,
#  present,
#  presented,
#  president,
#  pretty,
#  problem,
#  proof,
#  proposal,
#  provided,
#  pushed,
#  put,
#  rain,
#  ran,
#  read,
#  reading,
#  ready,
#  really,
#  red,
#  regarded,
#  remain,
#  remained,
#  remember,
#  report,
#  represented,
#  result,
#  reviewed,
#  rich,
#  ring,
#  river,
#  roof,
#  route,
#  said,
#  saw,
#  school,
#  secret,
#  seemed,
#  seriously,
#  set,
#  several,
#  she,
#  sheep,
#  should,
#  shows,
#  sidewalk,
#  sit,
#  sleep,
#  slid,
#  smith,
#  smoke,
#  so,
#  some,
#  somebody,
#  someone,
#  sound,
#  sounded,
#  speech,
#  spoke,
#  stick,
#  student,
#  students,
#  study,
#  studying,
#  submit,
#  sue,
#  sugar,
#  susan,
#  sweat,
#  swim,
#  table,
#  takes,
#  talked,
#  tall,
#  that,
#  the,
#  their,
#  themselves,
#  there,
#  they,
#  thinks,
#  this,
#  thought,
#  time,
#  to,
#  toast,
#  tom,
#  tomorrow,
#  tony,
#  too,
#  tree,
#  tried,
#  trouble,
#  truck,
#  tube,
#  under,
#  understood,
#  university,
#  up,
#  us,
#  very,
#  visit,
#  vote,
#  want,
#  wanted,
#  war,
#  was,
#  water,
#  we,
#  wears,
#  weighed,
#  what,
#  when,
#  where,
#  which,
#  while,
#  who,
#  whole,
#  whom,
#  will,
#  with,
#  without,
#  wo,
#  woman,
#  would,
#  writer,
#  yesterday,
#  york,
#  you,
#  young,
#  younger,
#  your,
#  yourself}

# %%
unknown_word = "UNK"

for non_terminal in non_terminals:
    productions.append(ProbabilisticProduction(non_terminal, [unknown_word]))

productions.append(ProbabilisticProduction(Nonterminal("UNK"), [unknown_word]))

# %%
for sent in modified_sentences:
    tokens = nltk.word_tokenize(sent)
    for token in tokens:
        productions.append(ProbabilisticProduction(Nonterminal(token), [f"{token}"]))

# %%
tic = time.perf_counter()
full_grammar = induce_pcfg(Nonterminal("S"), productions)
print(f"Took {time.perf_counter() - tic}s.")
# Out:
# Took 1.4109680999536067s.

# %%
modified_sentences[3]
# Out:
# 'the more does bill smoke , the more susan UNK him .'

# %%
parser = ViterbiParser(full_grammar)

# %%
from tqdm import tqdm

all_parses = []

for sentence in tqdm(modified_sentences, desc="Parsing Sentences"):
    tokens = nltk.word_tokenize(sentence)
    parses = parser.parse_all(tokens)
    
    for parse in parses:
        all_parses.append(parse)
# Out:
# Parsing Sentences:   2%|█▏                                                             | 3/162 [00:32<27:18, 10.30s/it]
